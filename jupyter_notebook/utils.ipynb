# %%
from utils.file_system_reader import FileSystemReader

# %%
STORIES_DATA_FILE = "stories_data.json"

# %%
req = FileSystemReader(STORIES_DATA_FILE)
data = req.read_file()
print(data)
# Out:
# [{'_id': '68ceaa41-e7eb-42b2-9414-a8f1083c6520', 'title': 'Aesop', 'description': "( 620  - 564 BCE ) was a Greek fabulist and storyteller credited with a number of fables now collectively known as Aesop's Fables. Although his existence remains unclear and no writings by him survive, numerous tales credited to him were gathered across the centuries and in many languages in a storytelling tradition that continues to this day. He is considered the founder of European fable poetry, and he addressed the common human weaknesses like envy, stupidity, avarice, and vanity.", 'origin': 'Aesop', 'story_description': [{'_id': '292f2009-96bb-4a3c-b856-e04214e852f8', 'vendorId': 'aesop01', 'storyTitle': 'The rabbit, the weasel and the cat', 'used': True, 'updatedOn': '2026-05-29T21:37:14.626015'}, {'_id': '345880b0-9a96-4d59-bebd-512ee0cc77f8', 'vendorId': 'aesop02', 'storyTitle': 'The lion and the mouse', 'used': False}, {'_id': '9f5cbe1e-453c-4a2f-9580-39c7285016dc', 'vendorId': 'aesop03', 'sto
# ...

# %%
req_id = "65b75de8-fe96-4748-90ca-661f45c74f95"

# %%
for category in data:

    for story in category.get("story_description", []):

        if story.get("_id") == req_id:
            print(story)
# Out:
# {'_id': '65b75de8-fe96-4748-90ca-661f45c74f95', 'vendorId': 'jataka03', 'storyTitle': 'Can a fool ever act good?', 'used': False}

# %%
for category in data:

    for story in category.get("story_description", []):

        if story.get("_id") == req_id:
            print(story.get("vendorId"))
# Out:
# jataka03

# %% [markdown]
# Get Stroy By Category

# %%
from utils.file_system_reader import FileSystemReader
TOKENIZED_STORIES = "tokenized_stories.json"

# %%
read_req = FileSystemReader(TOKENIZED_STORIES)
read_req = read_req.read_file()
print(read_req)
# Out:
# [{'title': {'englishversion': 'The trick of the crow', 'sanskritversion': 'काकस्य उपायः'}, 'actors': ['The trick of the crow'], 'storyMoral': '', 'englishVersion': ' Once there lived a crow with his wife in a nest on the top of a tree. In the hollow of the tree, a serpent was living which used to kill the young ones of the crows.\n           The friend of the crow, a jackal, made a plan to get rid of the serpent. He told the crow to fly to the palace and steal a necklace of the queen while she was bathing.\n          When the crow did so, the guards of the palace ran after him. The crow then dropped the necklace into the snake`s hollow.. When the king`s men found the necklace, they killed the serpent.', 'transliteratedVersion': ['kAkasya upAyaH', 'kazcana mahAvRkSaH AsIt |', 'tatra ekaH kAkaH patnyA saha vasati |', 'tasya eva vRkSasya koTare ekaH kRSNasarpaH api vasati sma |', 'yadA kAkI prasUtA bhavati tadA kRSNasarpaH tasyAH zAvakAn khAdati sma |', 'etena kAkaH kAkI ca mahat duHkha
# ...

# %%
category_story =[]
for story in read_req:
    if story["category"] == "pancha":
        category_story.append(story)


print(category_story)
# Out:
# [{'title': {'englishversion': 'The trick of the crow', 'sanskritversion': 'काकस्य उपायः'}, 'actors': ['The trick of the crow'], 'storyMoral': '', 'englishVersion': ' Once there lived a crow with his wife in a nest on the top of a tree. In the hollow of the tree, a serpent was living which used to kill the young ones of the crows.\n           The friend of the crow, a jackal, made a plan to get rid of the serpent. He told the crow to fly to the palace and steal a necklace of the queen while she was bathing.\n          When the crow did so, the guards of the palace ran after him. The crow then dropped the necklace into the snake`s hollow.. When the king`s men found the necklace, they killed the serpent.', 'transliteratedVersion': ['kAkasya upAyaH', 'kazcana mahAvRkSaH AsIt |', 'tatra ekaH kAkaH patnyA saha vasati |', 'tasya eva vRkSasya koTare ekaH kRSNasarpaH api vasati sma |', 'yadA kAkI prasUtA bhavati tadA kRSNasarpaH tasyAH zAvakAn khAdati sma |', 'etena kAkaH kAkI ca mahat duHkha
# ...

# %% [markdown]
# Get Story by Id

# %%
REQ_ID = "292f2009-96bb-4a3c-b856-e04214e852f8"

# %%
for story in read_req:
    if story["_id"] == REQ_ID:
    
        print(story)
# Out:
# {'title': {'englishversion': 'The rabbit, the weasel and the cat', 'sanskritversion': 'शशकः नकुलः मार्जारी च'}, 'actors': ['The rabbit', 'the weasel and the cat'], 'storyMoral': '(The strong can settle questions to their own advantage)', 'englishVersion': 'When the rabbit left his home, a weasel moved in and refused to move out again. A great dispute arose over this.  When the cat heard this, she offered to pacify the dispute. She asked the opponents to come closer to her, because she could not hear well. When this happened, she grabbed one of the disputants with each paw to devour them. Thus she pacified the quarrel.', 'transliteratedVersion': ['zazakaH nakulaH mArjArI ca', 'ekadine gRhAt prasthitaH ekaH zazakaH svAduM tRNaM khAditum agacchat ।', 'parantu gRhasya pidhAnaM kartuM saH vismRtavAn ।', 'yadA zazakaH gRhe na AsIt tadA ekaH nakulaH tatra Agatya zazakasya gRhaM praviSTavAn ।', 'tasmai zazakasya gRham arocata ataH tatraiva nivasituM nizcayaM kRtavAn ।', 'zazakaH Agatya nakul
# ...

# %% [markdown]
# Get All stories

# %%
read_req = FileSystemReader(TOKENIZED_STORIES)
read_req = read_req.read_file()
print(read_req)
# Out:
# [{'title': {'englishversion': 'The trick of the crow', 'sanskritversion': 'काकस्य उपायः'}, 'actors': ['The trick of the crow'], 'storyMoral': '', 'englishVersion': ' Once there lived a crow with his wife in a nest on the top of a tree. In the hollow of the tree, a serpent was living which used to kill the young ones of the crows.\n           The friend of the crow, a jackal, made a plan to get rid of the serpent. He told the crow to fly to the palace and steal a necklace of the queen while she was bathing.\n          When the crow did so, the guards of the palace ran after him. The crow then dropped the necklace into the snake`s hollow.. When the king`s men found the necklace, they killed the serpent.', 'transliteratedVersion': ['kAkasya upAyaH', 'kazcana mahAvRkSaH AsIt |', 'tatra ekaH kAkaH patnyA saha vasati |', 'tasya eva vRkSasya koTare ekaH kRSNasarpaH api vasati sma |', 'yadA kAkI prasUtA bhavati tadA kRSNasarpaH tasyAH zAvakAn khAdati sma |', 'etena kAkaH kAkI ca mahat duHkha
# ...

# %%
len(read_req)
# Out:
# 2

# %%
STORY_REQ_ID = "292f2009-96bb-4a3c-b856-e04214e852f8"

# %%
len(read_req)
# Out:
# 2

# %%
        for story in read_req:

            # safety check in case of bad data (like your earlier error)
            if not isinstance(story, dict):
                continue

            if story.get("_id") == STORY_REQ_ID:
                print(story)
# Out:
# {'title': {'englishversion': 'The rabbit, the weasel and the cat', 'sanskritversion': 'शशकः नकुलः मार्जारी च'}, 'actors': ['The rabbit', 'the weasel and the cat'], 'storyMoral': '(The strong can settle questions to their own advantage)', 'englishVersion': 'When the rabbit left his home, a weasel moved in and refused to move out again. A great dispute arose over this.  When the cat heard this, she offered to pacify the dispute. She asked the opponents to come closer to her, because she could not hear well. When this happened, she grabbed one of the disputants with each paw to devour them. Thus she pacified the quarrel.', 'transliteratedVersion': ['zazakaH nakulaH mArjArI ca', 'ekadine gRhAt prasthitaH ekaH zazakaH svAduM tRNaM khAditum agacchat ।', 'parantu gRhasya pidhAnaM kartuM saH vismRtavAn ।', 'yadA zazakaH gRhe na AsIt tadA ekaH nakulaH tatra Agatya zazakasya gRhaM praviSTavAn ।', 'tasmai zazakasya gRham arocata ataH tatraiva nivasituM nizcayaM kRtavAn ।', 'zazakaH Agatya nakul
# ...

# %%
from repository.get_tokenized_story_by_Id import GetTokenizedStoryById

# %%
req_story_call = GetTokenizedStoryById(STORY_REQ_ID)
req_story_call_result = req_story_call.retrieve_story()

# %%
print(req_story_call_result)
# Out:
# {'title': {'englishversion': 'The rabbit, the weasel and the cat', 'sanskritversion': 'शशकः नकुलः मार्जारी च'}, 'actors': ['The rabbit', 'the weasel and the cat'], 'storyMoral': '(The strong can settle questions to their own advantage)', 'englishVersion': 'When the rabbit left his home, a weasel moved in and refused to move out again. A great dispute arose over this.  When the cat heard this, she offered to pacify the dispute. She asked the opponents to come closer to her, because she could not hear well. When this happened, she grabbed one of the disputants with each paw to devour them. Thus she pacified the quarrel.', 'transliteratedVersion': ['zazakaH nakulaH mArjArI ca', 'ekadine gRhAt prasthitaH ekaH zazakaH svAduM tRNaM khAditum agacchat ।', 'parantu gRhasya pidhAnaM kartuM saH vismRtavAn ।', 'yadA zazakaH gRhe na AsIt tadA ekaH nakulaH tatra Agatya zazakasya gRhaM praviSTavAn ।', 'tasmai zazakasya gRham arocata ataH tatraiva nivasituM nizcayaM kRtavAn ।', 'zazakaH Agatya nakul
# ...

# %% [markdown]
# Get Story By Category

# %%
STORY_CATEGORY = "pancha"

# %%
for story in read_req:
    if not isinstance(story,dict):
        continue

    if story.get("category") == STORY_CATEGORY:
        print(story)
# Out:
# {'title': {'englishversion': 'The trick of the crow', 'sanskritversion': 'काकस्य उपायः'}, 'actors': ['The trick of the crow'], 'storyMoral': '', 'englishVersion': ' Once there lived a crow with his wife in a nest on the top of a tree. In the hollow of the tree, a serpent was living which used to kill the young ones of the crows.\n           The friend of the crow, a jackal, made a plan to get rid of the serpent. He told the crow to fly to the palace and steal a necklace of the queen while she was bathing.\n          When the crow did so, the guards of the palace ran after him. The crow then dropped the necklace into the snake`s hollow.. When the king`s men found the necklace, they killed the serpent.', 'transliteratedVersion': ['kAkasya upAyaH', 'kazcana mahAvRkSaH AsIt |', 'tatra ekaH kAkaH patnyA saha vasati |', 'tasya eva vRkSasya koTare ekaH kRSNasarpaH api vasati sma |', 'yadA kAkI prasUtA bhavati tadA kRSNasarpaH tasyAH zAvakAn khAdati sma |', 'etena kAkaH kAkI ca mahat duHkham
# ...
